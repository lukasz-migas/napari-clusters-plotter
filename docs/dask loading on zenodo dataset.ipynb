# %%
from dask_image.imread import imread
folder = 'E:/Science/Data/Lund Zenodo/'
filename_glob = 'lund_i*_oi_*.tif'

dask_stack = imread(folder + filename_glob)

# %%
import napari
viewer = napari.Viewer()
viewer.add_-image(dask_stack)
# Out:
# C:\Users\ryans\anaconda3\envs\ncp_dev_v2\lib\site-packages\napari_tools_menu\__init__.py:165: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [7], in <module>
#       1 import napari
#       2 viewer = napari.Viewer()
# ----> 3 viewer.add_image(dask_stack)
#
# ...

# %%
dask_stack
# Out:
# dask.array<_map_read_frame, shape=(431, 71, 1024, 512), dtype=uint16, chunksize=(1, 71, 1024, 512), chunktype=numpy.ndarray>

# %%
from skimage.io import imread
from skimage.io.collection import alphanumeric_key
from dask import delayed
import dask.array as da
from glob import glob

filenames = sorted(glob(folder+filename_glob), key=alphanumeric_key)
filenames
# Out:
# ['E:/Science/Data/Lund Zenodo\\lund_i000000_oi_000000.tif',
#  'E:/Science/Data/Lund Zenodo\\lund_i000001_oi_000005.tif',
#  'E:/Science/Data/Lund Zenodo\\lund_i000002_oi_000007.tif',
#  'E:/Science/Data/Lund Zenodo\\lund_i000003_oi_000008.tif',
#  'E:/Science/Data/Lund Zenodo\\lund_i000004_oi_000010.tif',
#  'E:/Science/Data/Lund Zenodo\\lund_i000005_oi_000011.tif',
#  'E:/Science/Data/Lund Zenodo\\lund_i000006_oi_000014.tif',
#  'E:/Science/Data/Lund Zenodo\\lund_i000007_oi_000016.tif',
#  'E:/Science/Data/Lund Zenodo\\lund_i000008_oi_000024.tif',
#  'E:/Science/Data/Lund Zenodo\\lund_i000009_oi_000037.tif',
#  'E:/Science/Data/Lund Zenodo\\lund_i000010_oi_000038.tif',
#  'E:/Science/Data/Lund Zenodo\\lund_i000011_oi_000040.tif',
#  'E:/Science/Data/Lund Zenodo\\lund_i000012_oi_000044.tif',
#  'E:/Science/Data/Lund Zenodo\\lund_i000013_oi_000059.tif',
#  'E:/Science/Data/Lund Zenodo\\lund_i000014_oi_000074.tif',
#  'E:/Science/Data/Lund Zenodo\\lund_i000015_oi_000081.tif',
# ...

# %%
from dask.array.image import imread
subset_folder = 'testset(cropped)/'
dask_stack_smaller = imread(folder + subset_folder + filename_glob)

# %%
dask_stack_smaller
# Out:
# dask.array<imread, shape=(89, 71, 1024, 512), dtype=uint16, chunksize=(1, 71, 1024, 512), chunktype=numpy.ndarray>

# %%
viewer2 = napari.Viewer()
viewer2.add_image(dask_stack_smaller, contrast_limits=[0,2000], multiscale=False)
# Out:
# C:\Users\ryans\anaconda3\envs\ncp_dev_v2\lib\site-packages\napari_tools_menu\__init__.py:165: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# <Image layer 'dask_stack_smaller' at 0x20cc29cd3d0>
